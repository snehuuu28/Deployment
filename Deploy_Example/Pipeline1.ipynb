# %%
import pickle

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
model = pickle.load(open('svm_model.pkl','rb'))

# %%
model
# Out:
# SVC()

# %%
model.predict([[6.3,2.5,5.0,1.9]])
# Out:
# array([2])

# %%
m1 = pickle.load(open('model.pkl','rb'))

# %%
m1.predict([[38,'male',25,'No']])
# Out:
# array([11397.39258102])

# %%
m1.predict([[21,'female',22,'Yes']])
# Out:
# array([29928.75366552])

# %%
def predict(age,gender,bmi,smoker):
    result = m1.predict([[age,gender,bmi,smoker]])
    return result

# %%
predict(25,'female',23,'No')
# Out:
# array([6865.98111921])
